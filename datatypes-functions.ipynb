# %%
c = 15 + 30j
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 15.0

# %%
c.imag
# Out:
# 30.0

# %%
k = 18 + 20j
l = 20 + 30j
k+ l
# Out:
# (38+50j)

# %%
type(k + l )
# Out:
# complex

# %%
k = 18 + 20j
l = 20 + 30j
k.real + l.real
# Out:
# 38.0

# %%
a =10
b=15
c = a + b
print(c)
type(c)
# Out:
# 25
# int

# %%
import keyword
print(keyword.kwlist)  
print(len(keyword.kwlist))   
print(keyword.kwlist[10])
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35
# continue

# %%
import sys
p=20
q=20
t=20
print(id(p))
print(id(q))
print(id(t))
p=q + t
print(p,'address-->  ' ,id(p))
print(id(q))
print(id(t))

print(sys.getsizeof(p))
# Out:
# 140726473500168
# 140726473500168
# 140726473500168
# 40 address-->   140726473500808
# 140726473500168
# 140726473500168
# 28

# %%
val2 = 92.78
print(val2)
print(type(val2))
print(sys.getsizeof(val2))
print(val2, " is float?", isinstance(val2, float))
# Out:
# 92.78
# <class 'float'>
# 24
# 92.78  is float? True

# %%
first_name ='John'
last_name = 'Doe'
full_name = first_name + ' ' + last_name
print(full_name)
type(full_name)
# Out:
# John Doe
# str

# %%
a = 5
b = 25
print(min(a, b))
max(a, b)
# Out:
# 5
# 25

# %% [markdown]
# Strings

# %%
mystring ='welcome to python programming'
print(mystring.upper())
print(mystring[-1])
print(mystring.split(' '))
# Out:
# WELCOME TO PYTHON PROGRAMMING
# g
# ['welcome', 'to', 'python', 'programming']

# %%
s2 = 'programming'
print(s2[0:5])  
print(s2[:])
print(s2[1:5:2])
# Out:
# progr
# programming
# rg

# %%
mystr = ('Happy '
'Monday ' 'Everyone')
print(mystr)

mystr = """Hello
   World""" # Define string using triple quotes
print(mystr)
# Out:
# Happy Monday Everyone
# Hello
#    World

# %%
str1 = "HELLO PYTHON"
print(str1.lower())
print(str1.count('O'))
# Out:
# hello python
# 2

# %%
str1 = "HELLO PYTHON"
str2 = "Programming"
print(str1 + ' ' + str2)
str3 = str1 + ' ' + str2 + ' is fun!'
print(str3)
# Out:
# HELLO PYTHON Programming
# HELLO PYTHON Programming is fun!
