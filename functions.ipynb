# %%
x = sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math
x = math.sqrt(25)
print(x)
print(round(x))
# Out:
# 5.0
# 5

# %%
print(math.floor(5.25))
print(math.ceil(5.25))
# Out:
# 5
# 6

# %%
print(math.pi)
pi = 3.8
print(pi)
# Out:
# 3.141592653589793
# 3.8

# %%
math.pow(2, 3)
# Out:
# 8.0

# %%
import math as m  # Alias for math module
print(m.sqrt(25))
print(m.pow(2, 3))
# Out:
# 5.0
# 8.0

# %% [markdown]
# input function

# %%
input()
# Out:
# 'hello'

# %%
x = input()
y = input()
z = x + y
print(z)
# Out:
# 1020

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
x = int(input())
y = int(input())
z = x + y
print(z)
# Out:
# 70

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x1 = input('Enter the 1st number') #whenevery you works in input function it always give you string 
y1 = input('Enter the 2nd number') # it wont understand as arithmetic operator
z1 = x1 + y1
print(z1)
# Out:
# 2030

# %%
st = input('enter a string')[0:2]
print(st)
# Out:
# he

# %%
st = input('enter a string')[9:13]
print(st)
# Out:
# s is
