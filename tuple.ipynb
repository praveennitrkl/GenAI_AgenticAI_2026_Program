# %% [markdown]
# Tuple

# %%
t = (1, 2, 3)
print(type(t))
print(t.count(3))
print(t.index(2))
# Out:
# <class 'tuple'>
# 1
# 1

# %%
t= (1, 2, 3, 4, 5)
t[0] = 6
print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 t= (1, 2, 3, 4, 5)
# ----> 2 t[0] = 6
#       3 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
t = (1, 2, 3)

print(t * 2) # repeats 2 times
print(t + (4, 5)) # concatenates two tuples
# Out:
# (1, 2, 3, 1, 2, 3)
# (1, 2, 3, 4, 5)
