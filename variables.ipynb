# %%
_int=5
_int
# Out:
# 5

# %%
abc='nitro'
abc
# Out:
# 'nitro'

# %% [markdown]
# Data types & Functions

# %%
i=10
i
# Out:
# 10

# %%
type(i)
# Out:
# int

# %%
id(i)
# Out:
# 140730851939528

# %%
price_pencil=5.5
price_pencil
# Out:
# 5.5

# %%
id(price_pencil)
# Out:
# 1421733061584

# %%
type(price_pencil)
# Out:
# float

# %%
print('hello world')
print(50 + 10)
print('the price of pencil is', price_pencil)   
print(50 / 5)
# Out:
# hello world
# 60
# the price of pencil is 5.5
# 10.0

# %%
f2=5.5e2
f2
# Out:
# 550.0

# %%
type(f2)
# Out:
# float

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True - True
# Out:
# 0

# %%
False / True
# Out:
# 0.0
