# %% [markdown]
# #Pandas Practice Session

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dateRanges = pd.date_range('20260601', periods=10)
dateRanges

df =pd.DataFrame(np.random.randint(0, 10, size=(10, 4)), index=dateRanges, columns=list('ABCD'))
df
# Out:
#             A  B  C  D
# 2026-06-01  0  3  4  1
# 2026-06-02  0  5  6  2
# 2026-06-03  7  3  4  9
# 2026-06-04  1  7  2  2
# 2026-06-05  1  7  8  9
# 2026-06-06  0  3  6  4
# 2026-06-07  4  2  5  3
# 2026-06-08  7  5  5  5
# 2026-06-09  9  9  2  6
# 2026-06-10  8  4  0  3

# %%
#Working with CSV files

customer_df = pd.read_csv('C:/Data Science AI Course/April 1/customers.csv')
customer_df.head()

customer_df.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')

# %%
calories = {"day1":40, "day2":50,"day3":90,"day4":55,"day5":60,"day6":70,"day7":80}
myVar = pd.Series(calories)
myVar.head()
# Out:
# day1    40
# day2    50
# day3    90
# day4    55
# day5    60
# dtype: int64

# %%
myvar2 = pd.Series(calories,index=["day3","day4","day5","day6","day7"])
myvar2
# Out:
# day3    90
# day4    55
# day5    60
# day6    70
# day7    80
# dtype: int64

# %%
myData = {
    "Calories":[500,600,400,300],
    "Duration":[50,60,40,30]
}
df = pd.DataFrame(myData)
df
# Out:
#    Calories  Duration
# 0       500        50
# 1       600        60
# 2       400        40
# 3       300        30

# %%
print(df.loc[2])
# Out:
# Calories    400
# Duration     40
# Name: 2, dtype: int64

# %%
print(df.loc[[2,3]])
# Out:
#    Calories  Duration
# 2       400        40
# 3       300        30

# %%
df = pd.read_csv(r'C:/Data Science AI Course/April 1/customers.csv')

df
# Out:
#     Index      Customer Id  First Name    Last Name  \
# 0       1  DD37Cf93aecA6Dc      Sheryl       Baxter
# 1       2  1Ef7b82A4CAAD10     Preston       Lozano
# 2       3  6F94879bDAfE5a6         Roy        Berry
# 3       4  5Cef8BFA16c5e3c       Linda        Olsen
# 4       5  053d585Ab6b3159      Joanna       Bender
# 5       6  2d08FB17EE273F4       Aimee        Downs
# 6       7  EA4d384DfDbBf77      Darren         Peck
# 7       8  0e04AFde9f225dE       Brett       Mullen
# 8       9  C2dE4dEEc489ae0      Sheryl       Meyers
# 9      10  8C2811a503C7c5a    Michelle    Gallagher
# 10     11  216E205d6eBb815        Carl    Schroeder
# 11     12  CEDec94deE6d69B       Jenna       Dodson
# 12     13  e35426EbDEceaFF      Tracey         Mata
# 13     14  A08A8aF8BE9FaD4    Kristine          Cox
# 14     15  6fEaA1b7cab7B6C       Faith         Lutz
# 15     16  8cad0b4CBceaeec     Miranda      Beasley
# 16     17  a5DC21AE3a21eaA    Caroline        Foley
# ...

# %%
dfJson = pd.read_json(r'C:/Data Science AI Course/April 1/data.json')
dfJson
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}
dfDict = pd.DataFrame(data)
dfDict
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
x = dfDict.Calories
print(x)
y = dfDict.Duration
print(y)

plt.plot(x, color='red', marker='o')
plt.plot(y, color='blue', marker='x')
plt.xticks(range(len(x)), np.array(dfDict.Duration) )
#plt.xticks(range(len(x)), np.array(dfDict.Duration)  )
plt.yticks(range(0, 550, 30))
plt.xlabel("Days")
plt.ylabel("Calories")
plt.show()
# Out:
# 0    409
# 1    479
# 2    340
# 3    282
# 4    406
# 5    300
# Name: Calories, dtype: int64
# 0    60
# 1    60
# 2    60
# 3    45
# 4    45
# 5    60
# Name: Duration, dtype: int64

# %%
excelDf = pd.read_excel(r'C:/Data Science AI Course/March 31/data.xlsx')
excelDf
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
dfCsv = pd.read_csv(r'C:/Data Science AI Course/April 1/customers.csv')

dfCsv.head(5)
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda                   -1199    (496)978-3969x58947
# ...

# %%
data = { 'A': np.array([1, 4, 7]),
         'B': np.array([2, 5, 8]),
         'C': np.array([3, 6, 9]) }
df = pd.DataFrame(data)
print(df)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
data = [
    {'name': 'Mike', 'degree': 'MBA', 'score': 90},
    {'name': 'Dan', 'degree': 'BCA', 'score': 40},
    {'name': 'Emilia', 'degree': 'M.Tech', 'score': 80},
]
df = pd.DataFrame(data)
df
# Out:
#      name  degree  score
# 0    Mike     MBA     90
# 1     Dan     BCA     40
# 2  Emilia  M.Tech     80

# %%
df2 = pd.DataFrame.from_dict(data)
df2
# Out:
#      name  degree  score
# 0    Mike     MBA     90
# 1     Dan     BCA     40
# 2  Emilia  M.Tech     80

# %%
df3 = pd.DataFrame.from_records(data)
df3
# Out:
#      name  degree  score
# 0    Mike     MBA     90
# 1     Dan     BCA     40
# 2  Emilia  M.Tech     80

# %%
listTouple = [('Mike', 'MBA', 90), ('Dan', 'BCA', 40), ('Emilia', 'M.Tech', 80)]
listTou = pd.DataFrame(listTouple, columns=['name', 'degree', 'score'])
listTou
# Out:
#      name  degree  score
# 0    Mike     MBA     90
# 1     Dan     BCA     40
# 2  Emilia  M.Tech     80

# %%
# initialize data of lists.
data = {'Name': ['Tom', 'Jack', 'nick', 'juli'],
        'marks': [99, 98, 95, 90]}

# Creates pandas DataFrame.
df4 = pd.DataFrame(data, index=['rank1',
                               'rank2',
                               'rank3',
                               'rank4'])
df4
# Out:
#        Name  marks
# rank1   Tom     99
# rank2  Jack     98
# rank3  nick     95
# rank4  juli     90

# %%
# initialize list of lists
data = [['tom', 10], ['nick', 15], ['juli', 14]]

# Create the pandas DataFrame
df5 = pd.DataFrame(data, columns=['Name', 'Age'])

print(df5)
# Out:
#    Name  Age
# 0   tom   10
# 1  nick   15
# 2  juli   14

# %%
df5.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
data = {'Name': ['Jake', 'Mike'],
        'Age': [25, 30],
        'Salary': [50000, 55000]}
df6 = pd.DataFrame(data)
res = df6.set_index('Name')
res = df6.set_axis(['John', 'Jane'])
res
# Out:
#       Name  Age  Salary
# John  Jake   25   50000
# Jane  Mike   30   55000

# %%
data = {'age': [25, 30], 'city': ['NY', 'LA']}
df = pd.DataFrame(data, index=['Alice', 'Bob'])
print(df)
print(df.loc['Alice'])
print(df['age'])
# Out:
#        age city
# Alice   25   NY
# Bob     30   LA
# age     25
# city    NY
# Name: Alice, dtype: object
# Alice    25
# Bob      30
# Name: age, dtype: int64

# %%
data3 = {'Name': ['John', 'Alice', 'Bob', 'Eve', 'Charlie'], 
        'Age': [25, 30, 22, 35, 28], 
        'Gender': ['Male', 'Female', 'Male', 'Female', 'Male'], 
        'Salary': [50000, 55000, 40000, 70000, 48000]}

df = pd.DataFrame(data3)
df
# Out:
#       Name  Age  Gender  Salary
# 0     John   25    Male   50000
# 1    Alice   30  Female   55000
# 2      Bob   22    Male   40000
# 3      Eve   35  Female   70000
# 4  Charlie   28    Male   48000

# %%
print(df['Age'])
print('\n')
print(df.iloc[3])
print('\n')
print(df.loc[2])
# Out:
# 0    25
# 1    30
# 2    22
# 3    35
# 4    28
# Name: Age, dtype: int64
#
#
# Name         Eve
# Age           35
# Gender    Female
# Salary     70000
# Name: 3, dtype: object
#
#
# Name        Bob
# Age          22
# Gender     Male
# Salary    40000
# Name: 2, dtype: object

# %%
salary_at_index_2 = df.at[2, 'Salary']
print(salary_at_index_2)
print(df.iat[4, 3])
# Out:
# 40000
# 48000
