# %% [markdown]
# #Pandas is one of the important data analysis tool kit ---- Pandas is a Package
# --> Using pandas library developer or data analyst fill missing data if they found in the project
# --> We can insert,delete the  records
# --> we can do data alignment
# --> We can do transformation and data aggrigation (Group by)
# -->Pandas slicing indexing and subsetting
# -->we can work with tables and joins, merging etc
# -->Read files (Any Files) using pandas

# %%
#Country GDP or Economic Data Analysis
#import the necessary pandas libraries
import pandas as pd
import matplotlib.pyplot as plt
version = pd.__version__
print(f"Pandas version: {version}")
# Out:
# Pandas version: 2.3.3

# %%
#Read the excel file and store it in a DataFrame
df = pd.read_excel(r'C:/Data Science AI Course/March 31/data.xlsx')
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
len(df) #length of the excel file ( rows in the excel file)
# Out:
# 195

# %%
df.shape #Shape of the excel file ( rows and columns in the excel file)
# Out:
# (195, 5)

# %%
df.columns #Columns in the excel file
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
len(df.columns ) #Number of columns in the excel file
# Out:
# 5

# %%
df.iloc[0:5] #
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.isnull() #Check for null values in the excel file
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isna() #Check for null values in the excel file
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isnull().sum() #Check for null values in the excel file and sum them up to get the total number of null values in each column
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
type(df) #Check the type of the DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
id(df) #Check the memory address of the DataFrame
# Out:
# 1688934897680

# %%
df.info() #Check the information about the DataFrame such as the number of non-null values, data types of each column, and memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
df.dtypes #Check the data types of each column in the DataFrame
# Out:
# CountryName       object
# CountryCode       object
# BirthRate        float64
# InternetUsers    float64
# IncomeGroup       object
# dtype: object

# %%
df.head() #Check the first 5 rows of the Excel file
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.tail() #Check the last 5 rows of the Excel file
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df.head(10) #Check the first 10 rows of the Excel file
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
df.head(10).sort_values(by='CountryName') #Check the first 10 rows of the Excel file and sort them by the 'CountryName' column
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 1           Afghanistan         AFG     35.253         5.9000
# 3               Albania         ALB     12.877        57.2000
# 2                Angola         AGO     45.985        19.1000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 0                 Aruba         ABW     10.244        78.9000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
# 4  United Arab Emirates         ARE     11.044        88.0000
#
#            IncomeGroup
# 1           Low income
# 3  Upper middle income
# 2  Upper middle income
# 7          High income
# 5          High income
# 6  Lower middle income
# 0          High income
# 8          High income
# 9          High income
# 4          High income

# %%
df[:] #Check all the rows of the Excel file
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df[:5] #Check the first 5 rows of the Excel file
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df[5:10] #Check the rows from index 5 to 9 of the Excel file
# Out:
#            CountryName CountryCode  BirthRate  InternetUsers  \
# 5            Argentina         ARG     17.716        59.9000
# 6              Armenia         ARM     13.308        41.9000
# 7  Antigua and Barbuda         ATG     16.447        63.4000
# 8            Australia         AUS     13.200        83.0000
# 9              Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
df[3:] #Check the rows from index 3 to the end of the Excel file
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# 5               Argentina         ARG     17.716           59.9
# 6                 Armenia         ARM     13.308           41.9
# 7     Antigua and Barbuda         ATG     16.447           63.4
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# 7            High income
# ..                   ...
# ...

# %%
df[0:200:20] #Check the rows from index 0 to 199 with a step of 20 in the Excel file
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244        78.9000          High income
# 20      Belarus         BLR     12.500        54.1700  Upper middle income
# 40   Costa Rica         CRI     15.022        45.9600  Upper middle income
# 60        Gabon         GAB     30.555         9.2000  Upper middle income
# 80        India         IND     20.291        15.1000  Lower middle income
# 100       Libya         LBY     21.425        16.5000  Upper middle income
# 120  Mozambique         MOZ     39.705         5.4000           Low income
# 140      Poland         POL      9.600        62.8492          High income
# 160    Suriname         SUR     18.455        37.4000  Upper middle income
# 180     Uruguay         URY     14.374        57.6900          High income

# %%
df[::10] #Check every 10th row of the Excel file starting from index 0
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %%
df[::-10] #Check every 10th row of the Excel file starting from the end of the file
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715        18.5000
# 184         Venezuela, RB         VEN     19.842        54.9000
# 174   Trinidad and Tobago         TTO     14.590        63.8000
# 164             Swaziland         SWZ     30.093        24.7000
# 154          Sierra Leone         SLE     36.729         1.7000
# 144      French Polynesia         PYF     16.393        56.8000
# 134                  Oman         OMN     20.419        66.4500
# 124              Malaysia         MYS     16.805        66.9700
# 114        Macedonia, FYR         MKD     11.222        65.2400
# 104               Lesotho         LSO     28.738         5.0000
# 94               Kiribati         KIR     29.044        11.5000
# 84                Iceland         ISL     13.400        96.5468
# 74   Hong Kong SAR, China         HKG      7.900        74.2000
# 64                 Guinea         GIN     37.337         1.6000
# ...

# %%
#Read the excel file and store it in a DataFrame
df2 = pd.read_excel(r'C:/Data Science AI Course/March 31/data-with-nulls.xlsx')

df2
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df2.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df2.isnull().sum() #Check for null values in the excel file and sum them up to get the total number of null values in each column
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        6
# InternetUsers    6
# IncomeGroup      0
# dtype: int64

# %% [markdown]
# Raw data Vs Clean
# Raw Data -- > The data set which has missing values
# Clean Data -- > The data set which does not have anymissing values
#
# converting from Raw data to Clean Data is called, Data Cleaning or Data Clensing

# %%
df.describe() #Get the statistical summary of the numerical columns in the DataFrame
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df[['CountryCode', 'BirthRate']] #Check the 'countrycode' column in the DataFrame
# Out:
#     CountryCode  BirthRate
# 0           ABW     10.244
# 1           AFG     35.253
# 2           AGO     45.985
# 3           ALB     12.877
# 4           ARE     11.044
# ..          ...        ...
# 190         YEM     32.947
# 191         ZAF     20.850
# 192         COD     42.394
# 193         ZMB     40.471
# 194         ZWE     35.715
#
# [195 rows x 2 columns]

# %%
#Split the data into Caegories and Numerical data

df_cat = df[['CountryName', 'CountryCode', 'IncomeGroup']] #Select the categorical columns in the DataFrame
#df_numerical_data = df.select_dtypes(include=['int64', 'float64']) #Select the numerical columns in the DataFrame
df_cat.head(1)
#df_cat
# Out:
#   CountryName CountryCode  IncomeGroup
# 0       Aruba         ABW  High income

# %%
df_num = df[['BirthRate', 'InternetUsers' ]] #Select the numerical columns in the DataFrame
df_num.head(1)
#df_num
# Out:
#    BirthRate  InternetUsers
# 0     10.244           78.9

# %%
print(df.shape)
print(df_cat.shape)
print(df_num.shape)
# Out:
# (195, 5)
# (195, 3)
# (195, 2)

# %%
print(df.columns) #Check the columns in the original DataFrame
print(df_cat.columns) #Check the columns in the categorical DataFrame
print(df_num.columns) #Check the columns in the numerical DataFrame
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')
# Index(['CountryName', 'CountryCode', 'IncomeGroup'], dtype='object')
# Index(['BirthRate', 'InternetUsers'], dtype='object')

# %% [markdown]
# Describe --> Descriptive statistics
# It provides details for Numarical data only

# %%
df.describe() #Get the statistical summary of the DataFrame such as count, mean, standard deviation, minimum, and maximum values for each column
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df_num.describe() #Get the statistical summary of the numerical DataFrame such as count, mean, standard deviation, minimum, and maximum values for each column
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df_cat.describe() #Get the statistical summary of the categorical DataFrame such as count, unique values, top value, and frequency of the top value for each column
# Out:
#        CountryName CountryCode  IncomeGroup
# count          195         195          195
# unique         195         195            4
# top          Aruba         ABW  High income
# freq             1           1           67

# %%
df['InternetUsers'] < 2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
df[df['InternetUsers'] < 2] #Check the rows where the 'InternetUsers' column has values less than 2 in the DataFrame
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
len(df[df['InternetUsers'] < 2]) #Check the number of rows where the 'InternetUsers' column has values less than 2 in the DataFrame
# Out:
# 9

# %%
df[df['BirthRate'] > 40] #Check the rows where the 'BirthRate' column has values less than 20 in the DataFrame
print(df[df['BirthRate'] > 40] ) #Check the rows where the 'BirthRate' column has values less than 20 in the DataFrame
print(len(df[df['BirthRate'] > 40] ) ) #Check the number of rows where the 'BirthRate' column has values less than 20 in the DataFrame
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
df[(df['BirthRate'] > 40) & (df['InternetUsers'] < 2)] #Check the rows where the 'BirthRate' column has values less than 20 and 'InternetUsers' column has values less than 2 in the DataFrame
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
df[df['IncomeGroup'] == 'High income'] #Check the rows where the 'IncomeGroup' column has values equal to 'High income' in the DataFrame
#print(len(df[df['IncomeGroup'] == 'High income'])) #Check the rows where the 'IncomeGroup' column has values equal to 'High income' in the DataFrame
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                    Aruba         ABW     10.244          78.90  High income
# 4     United Arab Emirates         ARE     11.044          88.00  High income
# 5                Argentina         ARG     17.716          59.90  High income
# 7      Antigua and Barbuda         ATG     16.447          63.40  High income
# 8                Australia         AUS     13.200          83.00  High income
# ..                     ...         ...        ...            ...          ...
# 174    Trinidad and Tobago         TTO     14.590          63.80  High income
# 180                Uruguay         URY     14.374          57.69  High income
# 181          United States         USA     12.500          84.20  High income
# 184          Venezuela, RB         VEN     19.842          54.90  High income
# 185  Virgin Islands (U.S.)         VIR     10.700          45.30  High income
#
# [67 rows x 5 columns]

# %%
df[df['IncomeGroup'] == 'Low income']  #Check the rows where the 'IncomeGroup' column has values equal to 'Low income' in the DataFrame
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 29   Central African Republic         CAF     34.076           3.50
# 38                    Comoros         COM     34.326           6.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# 64                     Guinea         GIN     37.337           1.60
# 65                Gambia, The         GMB     42.525          14.00
# 66              Guinea-Bissau         GNB     37.503           3.10
# 77                      Haiti         HTI     25.345          10.60
# 93                   Cambodia         KHM     24.462           6.80
# ...

# %%
#Unique values in the 'IncomeGroup' column
df['IncomeGroup'].unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
df['IncomeGroup'].nunique()
# Out:
# 4

# %%
df.columns = ['a','b','c','d','e']

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
df.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers', 'IncomeGroup']

# %%
df.columns
df.head(2)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0        Aruba         ABW     10.244           78.9  High income
# 1  Afghanistan         AFG     35.253            5.9   Low income

# %%
df['myCalc'] = df['BirthRate'] * df['InternetUsers'] #Create a new column 'myCalc' by multiplying the 'BirthRate' and 'InternetUsers' columns in the DataFrame

df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    myCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup', 'myCalc'],
#       dtype='object')

# %%
#axis=0 means drop the column and axis=1 means drop the row

df = df.drop('myCalc', axis=1) #Drop the 'myCalc' column from the DataFrame
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df3 = df.copy() #Create a copy of the DataFrame
df3
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %% [markdown]
# SEABORN INTRO

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.rcParams['figure.figsize'] = (8, 5) #Set the figure size for the plots

import warnings
warnings.filterwarnings('ignore') #Ignore warnings in the code execution

# %%
vis1 = sns.distplot(df['InternetUsers']) #Create a distribution plot for the 'InternetUsers' column in the DataFrame

# %%
vis2 = sns.displot(df['BirthRate'], bins=10) #Create a distribution plot for the 'BirthRate' column in the DataFrame

# %%
vis3 = sns.distplot(df['BirthRate'], bins=10) #Create a distribution plot for the 'BirthRate' column in the DataFrame

# %%
#Plot with Bi- Variant
vis4 = sns.boxplot(x=df['IncomeGroup'], y=df['BirthRate']) #Create a box plot for the 'IncomeGroup' column and 'BirthRate' column in the DataFrame

#outlier  statistics outlier is hte datapoint which is far from other ovservations is called outlier
#Outlier also called as ANOMALY Detection
#these outlier impact machine learning model performance and also impact the statistical analysis of the data
#To Adjust these Outlier we  will inroduce probability concept 
#which Algorith,

# %%
vis5 = sns.lmplot(data=df, x='InternetUsers', y='BirthRate') #Create a linear regression plot for the 'BirthRate' and 'InternetUsers' columns in the DataFrame

# %%
vis5 = sns.lmplot(data=df, x='InternetUsers', y='BirthRate',fit_reg= False) #Create a linear regression plot for the 'BirthRate' and 'InternetUsers' columns in the DataFrame

# %%
vis5 = sns.lmplot(data=df, x='InternetUsers', y='BirthRate',fit_reg= False,hue='IncomeGroup') #Create a linear regression plot for the 'BirthRate' and 'InternetUsers' columns in the DataFrame
